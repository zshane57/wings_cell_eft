# %% [markdown]
# # Fly species Identification using Wing Venation Patterns - A Deep Learning Approach

# %%
#!pip install grad-cam torchcam

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torchvision.transforms as tt
from sklearn.model_selection import train_test_split

# --- Image Classification Base Class ---
class ImageClassificationBase(nn.Module):
    def training_step(self, batch):
        "calculate loss for a batch of training data"
        images, labels = batch
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss

    def validation_step(self, batch):
        "calculate loss & accuracy for a batch of validation data"
        images, labels = batch
        out = self(images)                    # Generate predictions
        loss = F.cross_entropy(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_acc': acc}

    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}

    def epoch_end(self, epoch, result):
        print("Epoch [{}], train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['train_loss'], result['val_loss'], result['val_acc']))

def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))


# --- ResNet9 Model ---
def conv_block(in_channels, out_channels, pool=False):
    layers = [nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
              nn.BatchNorm2d(out_channels),
              nn.ReLU(inplace=True)]
    if pool: layers.append(nn.MaxPool2d(2))
    return nn.Sequential(*layers)

class ResNet9(ImageClassificationBase):
    def __init__(self, in_channels, num_classes):
        super().__init__()
        # Input: 128 x 3 x 64 x 64
        self.conv1 = conv_block(in_channels, 64) # 128 x 64 x 64 x 64
        self.conv2 = conv_block(64, 128, pool=True) # 128 x 128 x 32 x 32
        self.res1 = nn.Sequential(conv_block(128, 128), # 128 x 128 x 32 x 32
                                  conv_block(128, 128)) # 128 x 128 x 32 x 32

        self.conv3 = conv_block(128, 256, pool=True) # 128 x 256 x 16 x 16
        self.conv4 = conv_block(256, 512, pool=True) # 128 x 512 x 8 x 8
        self.res2 = nn.Sequential(conv_block(512, 512), # 128 x 512 x 8 x 8
                                  conv_block(512, 512)) # 128 x 512 x 8 x 8

        self.classifier = nn.Sequential(nn.AdaptiveMaxPool2d(1), # 128 x 512 x 1 x 1
                                        nn.Flatten(), # 128 x 512
                                        nn.Dropout(0.2),
                                        nn.Linear(512, num_classes))

    def forward(self, xb):
        out = self.conv1(xb)
        out = self.conv2(out)
        out = self.res1(out) + out
        out = self.conv3(out)
        out = self.conv4(out)
        out = self.res2(out) + out
        out = self.classifier(out)
        return out

# %%
# --- Data Preparation ---
train_data_dir = '/content/drive/MyDrive/mh_resnet/fold2/train'
test_data_dir = '/content/drive/MyDrive/mh_resnet/fold2/test'

train_dataset = ImageFolder(train_data_dir, tt.Compose([tt.Grayscale(),
                                                        tt.ToTensor()]))
test_dataset = ImageFolder(test_data_dir, tt.Compose([tt.Grayscale(),
                                                      tt.ToTensor()]))

train_ds, valid_ds = train_test_split(train_dataset, test_size = 0.2, random_state=42, stratify=train_dataset.targets)
test_ds = test_dataset

batch_size = 32

train_dl = DataLoader(train_ds,
                      batch_size,
                      shuffle=True,
                      num_workers=2,
                      pin_memory=True)

valid_dl = DataLoader(valid_ds,
                    batch_size,
                    num_workers=2,
                    pin_memory=True)

# %%
# --- Model Training ---
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device

    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl:
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

device = get_default_device()

train_dl = DeviceDataLoader(train_dl, device)
valid_dl = DeviceDataLoader(valid_dl, device)

@torch.no_grad()
def evaluate(model, val_loader):
    """Evaluates the model's performance on the validation set"""
    model.eval()
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

def fit(epochs, lr, model, train_loader, val_loader, opt_func=torch.optim.Adam):
    history = []
    optimizer = opt_func(model.parameters(), lr)
    for epoch in range(epochs):
        # Training Phase
        model.train()
        train_losses = []
        for batch in train_loader:
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        # Validation phase
        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        model.epoch_end(epoch, result)
        history.append(result)
    return history

model = to_device(ResNet9(1, len(train_dataset.classes)), device)

history = [evaluate(model, valid_dl)]
history += fit(40, 0.001, model, train_dl, valid_dl, torch.optim.Adam)
history += fit(40, 0.0001, model, train_dl, valid_dl, torch.optim.Adam)
history += fit(40, 0.00001, model, train_dl, valid_dl, torch.optim.Adam)
# Out:
# Epoch [0], train_loss: 4.5797, val_loss: 3.1010, val_acc: 0.0208
# Epoch [1], train_loss: 2.7720, val_loss: 3.4153, val_acc: 0.0208
# Epoch [2], train_loss: 2.5434, val_loss: 3.2695, val_acc: 0.0208
# Epoch [3], train_loss: 2.0517, val_loss: 2.8946, val_acc: 0.0208
# Epoch [4], train_loss: 1.9894, val_loss: 1.9954, val_acc: 0.3729
# Epoch [5], train_loss: 1.5212, val_loss: 1.6889, val_acc: 0.4694
# Epoch [6], train_loss: 1.1324, val_loss: 1.4408, val_acc: 0.5215
# Epoch [7], train_loss: 0.9705, val_loss: 1.0979, val_acc: 0.6153
# Epoch [8], train_loss: 0.8340, val_loss: 0.6241, val_acc: 0.8514
# Epoch [9], train_loss: 0.7743, val_loss: 1.1332, val_acc: 0.5646
# Epoch [10], train_loss: 0.5686, val_loss: 0.5299, val_acc: 0.8528
# Epoch [11], train_loss: 0.5557, val_loss: 0.4032, val_acc: 0.8931
# Epoch [12], train_loss: 0.4239, val_loss: 0.7273, val_acc: 0.7549
# Epoch [13], train_loss: 0.2822, val_loss: 0.5070, val_acc: 0.7965
# Epoch [14], train_loss: 0.3682, val_loss: 0.7609, val_acc: 0.7799
# Epoch [15], train_loss: 0.2174, val_loss: 0.2245, val_acc: 0.9465
# Epoch [16], train_loss: 0.1588, val_loss: 0.2421, val_acc: 0.9375
# Epoch [17], train_loss: 0.0913, val_loss: 0.7319, val_acc: 0.8292
# Epoch [18], train_loss: 0.1204, val_loss: 0.2961, val_acc: 0.9375
# Epoch [19], train_loss: 0.1128, val_loss: 0.1819, val_acc: 0.9792
# Epoch [20], train_loss: 0.0983, val_loss: 0.4712, val_acc: 0.8410
# Epoch [21], train_loss: 0.0869, val_loss: 0.2316, val_acc: 0.9583
# Epoch [22], train_loss: 0.0973, val_loss: 0.1649, val_acc: 0.9792
# Epoch [23], train_loss: 0.0599, val_loss: 0.2918, val_acc: 0.9167
# Epoch [24], train_loss: 0.0839, val_loss: 0.7753, val_acc: 0.7028
# Epoch [25], train_loss: 0.0654, val_loss: 0.1760, val_acc: 0.9569
# Epoch [26], train_loss: 0.0540, val_loss: 0.3173, val_acc: 0.9153
# Epoch [27], train_loss: 0.0518, val_loss: 0.4009, val_acc: 0.8319
# Epoch [28], train_loss: 0.0783, val_loss: 0.0996, val_acc: 0.9896
# Epoch [29], train_loss: 0.0309, val_loss: 0.2162, val_acc: 0.9583
# Epoch [30], train_loss: 0.0164, val_loss: 0.1651, val_acc: 0.9792
# Epoch [31], train_loss: 0.0171, val_loss: 0.1654, val_acc: 0.9792
# Epoch [32], train_loss: 0.0121, val_loss: 0.1574, val_acc: 0.9792
# Epoch [33], train_loss: 0.0118, val_loss: 0.1650, val_acc: 0.9688
# Epoch [34], train_loss: 0.0046, val_loss: 0.1394, val_acc: 0.9896
# Epoch [35], train_loss: 0.0089, val_loss: 0.3092, val_acc: 0.9243
# Epoch [36], train_loss: 0.0238, val_loss: 0.1884, val_acc: 0.9583
# Epoch [37], train_loss: 0.0180, val_loss: 0.1249, val_acc: 0.9792
# Epoch [38], train_loss: 0.0332, val_loss: 0.1934, val_acc: 0.9583
# Epoch [39], train_loss: 0.0302, val_loss: 0.1878, val_acc: 0.9792
# Epoch [0], train_loss: 0.0102, val_loss: 0.1532, val_acc: 0.9792
# Epoch [1], train_loss: 0.0054, val_loss: 0.1157, val_acc: 0.9896
# Epoch [2], train_loss: 0.0052, val_loss: 0.1144, val_acc: 0.9896
# Epoch [3], train_loss: 0.0042, val_loss: 0.1211, val_acc: 0.9896
# Epoch [4], train_loss: 0.0018, val_loss: 0.1406, val_acc: 0.9792
# Epoch [5], train_loss: 0.0013, val_loss: 0.1433, val_acc: 0.9792
# Epoch [6], train_loss: 0.0013, val_loss: 0.1322, val_acc: 0.9896
# Epoch [7], train_loss: 0.0010, val_loss: 0.1233, val_acc: 0.9896
# Epoch [8], train_loss: 0.0049, val_loss: 0.1204, val_acc: 0.9896
# Epoch [9], train_loss: 0.0263, val_loss: 0.1053, val_acc: 0.9896
# Epoch [10], train_loss: 0.0057, val_loss: 0.1644, val_acc: 0.9688
# Epoch [11], train_loss: 0.0018, val_loss: 0.1129, val_acc: 0.9896
# Epoch [12], train_loss: 0.0075, val_loss: 0.1410, val_acc: 0.9792
# Epoch [13], train_loss: 0.0053, val_loss: 0.1289, val_acc: 0.9896
# Epoch [14], train_loss: 0.0016, val_loss: 0.1375, val_acc: 0.9896
# Epoch [15], train_loss: 0.0008, val_loss: 0.1389, val_acc: 0.9896
# Epoch [16], train_loss: 0.0002, val_loss: 0.1388, val_acc: 0.9896
# Epoch [17], train_loss: 0.0006, val_loss: 0.1401, val_acc: 0.9896
# Epoch [18], train_loss: 0.0005, val_loss: 0.1385, val_acc: 0.9896
# Epoch [19], train_loss: 0.0003, val_loss: 0.1353, val_acc: 0.9896
# Epoch [20], train_loss: 0.0005, val_loss: 0.1379, val_acc: 0.9896
# Epoch [21], train_loss: 0.0004, val_loss: 0.1389, val_acc: 0.9896
# Epoch [22], train_loss: 0.0003, val_loss: 0.1387, val_acc: 0.9896
# Epoch [23], train_loss: 0.0003, val_loss: 0.1370, val_acc: 0.9896
# Epoch [24], train_loss: 0.0001, val_loss: 0.1358, val_acc: 0.9896
# Epoch [25], train_loss: 0.0003, val_loss: 0.1332, val_acc: 0.9896
# Epoch [26], train_loss: 0.0006, val_loss: 0.1352, val_acc: 0.9896
# Epoch [27], train_loss: 0.0006, val_loss: 0.1426, val_acc: 0.9896
# Epoch [28], train_loss: 0.0008, val_loss: 0.1434, val_acc: 0.9896
# Epoch [29], train_loss: 0.0010, val_loss: 0.1377, val_acc: 0.9896
# Epoch [30], train_loss: 0.0004, val_loss: 0.1380, val_acc: 0.9896
# Epoch [31], train_loss: 0.0002, val_loss: 0.1398, val_acc: 0.9896
# Epoch [32], train_loss: 0.0010, val_loss: 0.1711, val_acc: 0.9792
# Epoch [33], train_loss: 0.0118, val_loss: 0.6299, val_acc: 0.8722
# Epoch [34], train_loss: 0.0055, val_loss: 0.1233, val_acc: 0.9792
# Epoch [35], train_loss: 0.0127, val_loss: 0.1285, val_acc: 0.9896
# Epoch [36], train_loss: 0.0132, val_loss: 0.1361, val_acc: 0.9792
# Epoch [37], train_loss: 0.0075, val_loss: 0.1402, val_acc: 0.9688
# Epoch [38], train_loss: 0.0100, val_loss: 0.1301, val_acc: 0.9583
# Epoch [39], train_loss: 0.0068, val_loss: 0.1683, val_acc: 0.9792
# Epoch [0], train_loss: 0.0022, val_loss: 0.1558, val_acc: 0.9792
# Epoch [1], train_loss: 0.0007, val_loss: 0.1515, val_acc: 0.9896
# Epoch [2], train_loss: 0.0008, val_loss: 0.1505, val_acc: 0.9896
# Epoch [3], train_loss: 0.0010, val_loss: 0.1511, val_acc: 0.9896
# Epoch [4], train_loss: 0.0002, val_loss: 0.1505, val_acc: 0.9896
# Epoch [5], train_loss: 0.0004, val_loss: 0.1499, val_acc: 0.9896
# Epoch [6], train_loss: 0.0007, val_loss: 0.1500, val_acc: 0.9896
# Epoch [7], train_loss: 0.0003, val_loss: 0.1502, val_acc: 0.9896
# Epoch [8], train_loss: 0.0004, val_loss: 0.1494, val_acc: 0.9896
# Epoch [9], train_loss: 0.0004, val_loss: 0.1484, val_acc: 0.9896
# Epoch [10], train_loss: 0.0004, val_loss: 0.1494, val_acc: 0.9896
# Epoch [11], train_loss: 0.0011, val_loss: 0.1546, val_acc: 0.9896
# Epoch [12], train_loss: 0.0002, val_loss: 0.1574, val_acc: 0.9896
# Epoch [13], train_loss: 0.0007, val_loss: 0.1575, val_acc: 0.9896
# Epoch [14], train_loss: 0.0008, val_loss: 0.1563, val_acc: 0.9896
# Epoch [15], train_loss: 0.0002, val_loss: 0.1547, val_acc: 0.9896
# Epoch [16], train_loss: 0.0003, val_loss: 0.1546, val_acc: 0.9896
# Epoch [17], train_loss: 0.0006, val_loss: 0.1464, val_acc: 0.9896
# Epoch [18], train_loss: 0.0004, val_loss: 0.1435, val_acc: 0.9896
# Epoch [19], train_loss: 0.0003, val_loss: 0.1418, val_acc: 0.9896
# Epoch [20], train_loss: 0.0002, val_loss: 0.1410, val_acc: 0.9896
# Epoch [21], train_loss: 0.0004, val_loss: 0.1428, val_acc: 0.9896
# Epoch [22], train_loss: 0.0003, val_loss: 0.1458, val_acc: 0.9896
# Epoch [23], train_loss: 0.0003, val_loss: 0.1461, val_acc: 0.9896
# Epoch [24], train_loss: 0.0003, val_loss: 0.1456, val_acc: 0.9896
# Epoch [25], train_loss: 0.0002, val_loss: 0.1467, val_acc: 0.9896
# Epoch [26], train_loss: 0.0004, val_loss: 0.1459, val_acc: 0.9896
# Epoch [27], train_loss: 0.0001, val_loss: 0.1459, val_acc: 0.9896
# Epoch [28], train_loss: 0.0003, val_loss: 0.1465, val_acc: 0.9896
# Epoch [29], train_loss: 0.0001, val_loss: 0.1470, val_acc: 0.9896
# Epoch [30], train_loss: 0.0001, val_loss: 0.1475, val_acc: 0.9896
# Epoch [31], train_loss: 0.0003, val_loss: 0.1482, val_acc: 0.9896
# Epoch [32], train_loss: 0.0001, val_loss: 0.1487, val_acc: 0.9896
# Epoch [33], train_loss: 0.0001, val_loss: 0.1488, val_acc: 0.9896
# Epoch [34], train_loss: 0.0001, val_loss: 0.1487, val_acc: 0.9896
# Epoch [35], train_loss: 0.0001, val_loss: 0.1488, val_acc: 0.9896
# Epoch [36], train_loss: 0.0011, val_loss: 0.1454, val_acc: 0.9896
# Epoch [37], train_loss: 0.0001, val_loss: 0.1447, val_acc: 0.9896
# Epoch [38], train_loss: 0.0005, val_loss: 0.1465, val_acc: 0.9896
# Epoch [39], train_loss: 0.0001, val_loss: 0.1477, val_acc: 0.9896

# %%
# --- Plotting ---
import matplotlib.pyplot as plt

def plot_accuracies(history):
    accuracies = [x['val_acc'] for x in history]
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs. No. of epochs')

def plot_losses(history):
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['val_loss'] for x in history]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs. No. of epochs')

plot_accuracies(history)
plt.show()
plot_losses(history)
plt.show()

# %%
# Create a mapping from species to family
def familyClass(species_name):
  if species_name in ['C.vicina', 'Ch.albiceps', 'Ch.albiceps_mutant', 'Ch.bezziana', 'Ch.megacephala', 'Ch.nigripes', 'Ch.rufifacies', 'L.sericata']:
    return 'Calliphoridae'
  elif species_name in ['B.karnyi', 'Z.aquila', 'Le.alba', 'Se.princeps', 'A.gressitti']:
    return 'Sarcophagidae'
  else:
    return 'Muscidae'

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import os
import pandas as pd

# Create a DataLoader for the test set to perform evaluation on all test images
test_dl = DeviceDataLoader(DataLoader(test_dataset, batch_size*2), device)

def get_predictions(model, loader):
    model.eval()
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for batch in loader:
            images, labels = batch
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    return all_preds, all_labels

# Get predictions on the full test set
y_pred, y_true = get_predictions(model, test_dl)

# Get class names
class_names = train_dataset.classes

# --- Analyze incorrect predictions ---
# --- Create a DataFrame with predictions ---

# Create a list of dictionaries with all the required information
predictions_list = []
for i in range(len(y_true)):
    img_path, _ = test_dataset.samples[i]
    true_species = class_names[y_true[i]]
    pred_species = class_names[y_pred[i]]
    true_family = familyClass(true_species)
    pred_family = familyClass(pred_species)

    predictions_list.append({
        'sample_name': os.path.basename(img_path),
        'species': true_species,
        'Prediction': pred_species,
        'TargetFamily': true_family,
        'PredictionFamily': pred_family,
        'Match': true_species == pred_species,
        'MatchFamily': true_family == pred_family
    })

# Create the DataFrame
test_df = pd.DataFrame(predictions_list)

# Display the wrongly predicted rows
wrong_predictions = test_df[test_df['Match'] == False]
print("Wrongly predicted rows:")
display(wrong_predictions[['sample_name', 'species', 'Prediction', 'TargetFamily','PredictionFamily']])


# --- Performance Metrics ---
def calculate_metrics(y_true, y_pred, class_names, labels=None):
    report = classification_report(y_true, y_pred, target_names=class_names, output_dict=True, zero_division=0, labels=labels)
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    sensitivity = np.diag(cm) / np.sum(cm, axis=1)
    specificity = []
    for i in range(len(class_names)):
        tn = np.sum(np.delete(np.delete(cm, i, axis=0), i, axis=1))
        fp = np.sum(cm[:, i]) - cm[i, i]
        if (tn + fp) == 0:
            specificity.append(1.0)
        else:
            specificity.append(tn / (tn + fp))

    balanced_accuracy = (sensitivity + np.array(specificity)) / 2

    return report, sensitivity, specificity, balanced_accuracy

# Species-level metrics
report_species, sensitivity_species, specificity_species, balanced_accuracy_species = calculate_metrics(y_true, y_pred, class_names, labels=np.arange(len(class_names)))

print("\n--- Species Level Metrics ---")
print(classification_report(y_true, y_pred, target_names=class_names, zero_division=0))
avg_sensitivity_species = np.mean(sensitivity_species)
avg_specificity_species = np.mean(specificity_species)
avg_balanced_accuracy_species = np.mean(balanced_accuracy_species)
print(f"Averaged Sensitivity (Recall): {avg_sensitivity_species:.4f}")
print(f"Averaged Specificity: {avg_specificity_species:.4f}")
print(f"Averaged Balanced Accuracy: {avg_balanced_accuracy_species:.4f}")
print("Test set accuracy (Species Level) = {:.2f}% ({} / {})".format(
    test_df['Match'].sum() / len(test_df) * 100, test_df['Match'].sum(), len(test_df)
))
# Out:
# Wrongly predicted rows:
#              sample_name         species     Prediction   TargetFamily  \
# 80  C.megacephala.17.png  Ch.megacephala    Ch.bezziana  Calliphoridae
# 84  C.megacephala.36.png  Ch.megacephala    Ch.bezziana  Calliphoridae
# 86  C.megacephala.41.png  Ch.megacephala  Ch.rufifacies  Calliphoridae
# 93   C.megacephala.8.png  Ch.megacephala    Ch.bezziana  Calliphoridae
#
#    PredictionFamily
# 80    Calliphoridae
# 84    Calliphoridae
# 86    Calliphoridae
# 93    Calliphoridae
# --- Species Level Metrics ---
#                     precision    recall  f1-score   support
#
#        A.gressitti       1.00      1.00      1.00         3
#           B.karnyi       1.00      1.00      1.00         4
#           C.vicina       1.00      1.00      1.00        20
#        Ch.albiceps       1.00      1.00      1.00        20
# Ch.albiceps_mutant       1.00      1.00      1.00        20
#        Ch.bezziana       0.79      1.00      0.88        11
#     Ch.megacephala       1.00      0.75      0.86        16
#        Ch.nigripes       1.00      1.00      1.00         2
#      Ch.rufifacies       0.89      1.00      0.94         8
#         L.sericata       1.00      1.00      1.00        20
#            Le.alba       1.00      1.00      1.00         2
#        Se.princeps       1.00      1.00      1.00         3
#        Sy.nudiseta       1.00      1.00      1.00        20
#           Z.aquila       1.00      1.00      1.00         4
#
#           accuracy                           0.97       153
#          macro avg       0.98      0.98      0.98       153
#       weighted avg       0.98      0.97      0.97       153
#
# Averaged Sensitivity (Recall): 0.9821
# Averaged Specificity: 0.9980
# Averaged Balanced Accuracy: 0.9901
# Test set accuracy (Species Level) = 97.39% (149 / 153)
#
# --- Family Level Metrics ---
#                precision    recall  f1-score   support
#
# Calliphoridae       1.00      1.00      1.00       117
#      Muscidae       1.00      1.00      1.00        20
# Sarcophagidae       1.00      1.00      1.00        16
#
#      accuracy                           1.00       153
#     macro avg       1.00      1.00      1.00       153
#  weighted avg       1.00      1.00      1.00       153
#
# Averaged Sensitivity (Recall): 1.0000
# Averaged Specificity: 1.0000
# Averaged Balanced Accuracy: 1.0000
# Test set accuracy (Family Level) = 100.00% (153 / 153)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, class_names, title='Confusion Matrix'):
    plt.figure(figsize=(9, 7))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title(title)
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

# Species-level confusion matrix
cm_species = confusion_matrix(y_true, y_pred, labels=np.arange(len(class_names)))
plot_confusion_matrix(cm_species, class_names, title='Species-level Confusion Matrix')
